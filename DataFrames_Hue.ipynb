# %%
import pandas as pd

#Method 1: Specify full path of the file
stats = pd.read_csv('D:\\Trainings\\R and Python Classes\\Python Programming Course\\Class 2 - Data Frames\\DemographicData.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 
       'IncomeGroup']

stats =  stats[[ 'CountryCode', 'BirthRate', 'InternetUsers', 
       'IncomeGroup','CountryName']]

# %%
stats
# Out:
#     CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0           ABW     10.244       78.90000          High income
# 1           AFG     35.253        5.90000           Low income
# 2           AGO     45.985       19.10000  Upper middle income
# 3           ALB     12.877       57.20000  Upper middle income
# 4           ARE     11.044       88.00000          High income
# 5           ARG     17.716       59.90000          High income
# 6           ARM     13.308       41.90000  Lower middle income
# 7           ATG     16.447       63.40000          High income
# 8           AUS     13.200       83.00000          High income
# 9           AUT      9.400       80.61880          High income
# 10          AZE     18.300       58.70000  Upper middle income
# 11          BDI     44.151        1.30000           Low income
# 12          BEL     11.200       82.17020          High income
# 13          BEN     36.440        4.90000           Low income
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(stats["InternetUsers"])

# %%
sns.boxplot(data=stats, x="IncomeGroup", y="BirthRate")

# %%
sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', fit_reg=False, col='IncomeGroup')

# %%
stats.BirthRate * stats.InternetUsers
# Out:
# 0       808.251600
# 1       207.992700
# 2       878.313500
# 3       736.564400
# 4       971.872000
# 5      1061.188400
# 6       557.605200
# 7      1042.739800
# 8      1095.600000
# 9       757.816720
# 10     1074.210000
# 11       57.396300
# 12      920.306240
# 13      178.556000
# 14      369.014100
# 15      133.541460
# 16      488.165800
# 17     1353.600597
# 18     1104.408000
# 19      523.692980
# 20      677.125000
# 21      775.891200
# 22      991.120000
# 23      895.277840
# 24      762.078240
# 25      889.724000
# 26     1058.122500
# 27      542.206600
# 28      379.005000
# 29      119.266000
#           ...
# 165     937.440000
# 166     629.926600
# 167     105.213500
# 168     162.360000
# 169     319.526540
# 170     492.672000
# 171     204.691200
# 172      39.330500
# 173     889.315000
# 174     930.842000
# 175     867.240000
# 176     778.665000
# 177     173.879200
# 178     704.278800
# 179     455.100000
# 180     829.236060
# ...
