# %%
import pandas as pd

# %%
student_detail = {'student_id' : ['1234','2345','4343','4434'],
                 'FirstName': ['Alex','Hugo','Ben','Charlie'],
                 'LastName': ['White','Mathews','Thomas','Cook']}

# %%
student_details = pd.DataFrame(student_detail, columns=['student_id','FirstName','LastName'])

# %%
student_details
# Out:
#   student_id FirstName LastName
# 0       1234      Alex    White
# 1       2345      Hugo  Mathews
# 2       4343       Ben   Thomas
# 3       4434   Charlie     Cook

# %%
course_details = {'std_id':['1234','2345','4343','5456'],
                 'course': ['DS','ML','Tableau','DS'],
                 'Duration':[2,3,2,2]}

# %%
course_detail = pd.DataFrame(course_details)

# %%
course_detail
# Out:
#   std_id   course  Duration
# 0   1234       DS         2
# 1   2345       ML         3
# 2   4343  Tableau         2
# 3   5456       DS         2

# %%
pd.concat([student_details, course_detail], axis=1)
# Out:
#   student_id FirstName LastName std_id   course  Duration
# 0       1234      Alex    White   1234       DS         2
# 1       2345      Hugo  Mathews   2345       ML         3
# 2       4343       Ben   Thomas   4343  Tableau         2
# 3       4434   Charlie     Cook   5456       DS         2

# %%
pd.merge(student_details,course_detail, 
         left_on='student_id', right_on='std_id', how='left')
# Out:
#   student_id FirstName LastName std_id   course  Duration
# 0       1234      Alex    White   1234       DS       2.0
# 1       2345      Hugo  Mathews   2345       ML       3.0
# 2       4343       Ben   Thomas   4343  Tableau       2.0
# 3       4434   Charlie     Cook    NaN      NaN       NaN

# %%
type(student_details['FirstName'])
# Out:
# pandas.core.series.Series

# %%
student_details[1:3]
# Out:
#   student_id FirstName LastName
# 1       2345      Hugo  Mathews
# 2       4343       Ben   Thomas

# %%
import os

# %%
os.chdir('D:\\Cognitior\\Courses\\DSPY1 - Pro Data Science\\01. Codes and Datasets\\')

# %%
os.getcwd()
# Out:
# 'D:\\Cognitior\\Courses\\DSPY1 - Pro Data Science\\01. Codes and Datasets'

# %%
os.chdir('')

# %%
tips = pd.read_csv('tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
select total_bill, tip, smoker, time from tips limit 5;
# Out:
#   File "<ipython-input-38-691e0b11c324>", line 1
#     select total_bill, tip, smoker, time from tips limit 5;
#                     ^
# SyntaxError: invalid syntax

# %%
tips[['total_bill','tip','smoker','time']].tail(6)
# Out:
#      total_bill   tip smoker    time
# 238       35.83  4.67     No  Dinner
# 239       29.03  5.92     No  Dinner
# 240       27.18  2.00    Yes  Dinner
# 241       22.67  2.00    Yes  Dinner
# 242       17.82  1.75     No  Dinner
# 243       18.78  3.00     No  Dinner

# %%
select * from tips where time='Dinner' limit 5;

# %%
tips[tips['time']=='Dinner'].head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
select * from tips where time=Dinner and tip >5

# %%
tips[(tips['time']=='Dinner') & (tips['tip']>5)]
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 44        30.40   5.60    Male     No  Sun  Dinner     4
# 47        32.40   6.00    Male     No  Sun  Dinner     4
# 52        34.81   5.20  Female     No  Sun  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 116       29.93   5.07    Male     No  Sun  Dinner     4
# 155       29.85   5.14  Female     No  Sun  Dinner     5
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2
# 181       23.33   5.65    Male    Yes  Sun  Dinner     2
# 183       23.17   6.50    Male    Yes  Sun  Dinner     4
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3
# 239       29.03   5.92    Male     No  Sat  Dinner     3

# %%
select * from tips where size > 5 or total_bill >40

# %%
tips[(tips['size']>5) | (tips['total_bill']>40)]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 125       29.80   4.20  Female     No  Thur   Lunch     6
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 143       27.05   5.00  Female     No  Thur   Lunch     6
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
select * from data where col is null

# %%
tips[tips['total_bill'].notna()]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips[tips['total_bill'].isna()]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
select sex, count(*) from tips group by sex

# %%
tips.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
select day, avg(totalbill), count() from tips group by day

# %%
import numpy as np

# %%
tips.groupby('day').agg({'tip':np.mean, 'day':np.size})
# Out:
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %%
select smoker, day, count(*), avg(totalbill) from tips group by smoker, day

# %%
tips.groupby(['smoker','day']).agg({'total_bill':[np.size, np.mean],
                                   'tip':[np.size, np.mean]})
# Out:
#             total_bill              tip
#                   size       mean  size      mean
# smoker day
# No     Fri         4.0  18.420000   4.0  2.812500
#        Sat        45.0  19.661778  45.0  3.102889
#        Sun        57.0  20.506667  57.0  3.167895
#        Thur       45.0  17.113111  45.0  2.673778
# Yes    Fri        15.0  16.813333  15.0  2.714000
#        Sat        42.0  21.276667  42.0  2.875476
#        Sun        19.0  24.120000  19.0  3.516842
#        Thur       17.0  19.190588  17.0  3.030000

# %%
os.chdir('D:\\Trainings\\R and Python Classes\\Python Programming Course\\Class 2 - Data Frames\\')

# %%
stats = pd.read_csv('DemographicData.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
len(stats)
# Out:
# 195

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.columns= [['CountryName','CountryCode','Birthrate','Internetusers','IncomeGroup']]

# %%
stats = stats[['CountryName','CountryCode','Birthrate','Internetusers','IncomeGroup']]

# %%
stats
# Out:
#                         CountryName CountryCode Birthrate Internetusers  \
# 0                             Aruba         ABW    10.244      78.90000
# 1                       Afghanistan         AFG    35.253       5.90000
# 2                            Angola         AGO    45.985      19.10000
# 3                           Albania         ALB    12.877      57.20000
# 4              United Arab Emirates         ARE    11.044      88.00000
# 5                         Argentina         ARG    17.716      59.90000
# 6                           Armenia         ARM    13.308      41.90000
# 7               Antigua and Barbuda         ATG    16.447      63.40000
# 8                         Australia         AUS    13.200      83.00000
# 9                           Austria         AUT     9.400      80.61880
# 10                       Azerbaijan         AZE    18.300      58.70000
# 11                          Burundi         BDI    44.151       1.30000
# ...

# %%
stats[12:15]
# Out:
#      CountryName CountryCode Birthrate Internetusers  IncomeGroup
# 12       Belgium         BEL    11.200       82.1702  High income
# 13         Benin         BEN    36.440        4.9000   Low income
# 14  Burkina Faso         BFA    40.551        9.1000   Low income

# %%
stats[::-1]
# Out:
#                         CountryName CountryCode Birthrate Internetusers  \
# 194                        Zimbabwe         ZWE    35.715      18.50000
# 193                          Zambia         ZMB    40.471      15.40000
# 192                Congo, Dem. Rep.         COD    42.394       2.20000
# 191                    South Africa         ZAF    20.850      46.50000
# 190                     Yemen, Rep.         YEM    32.947      20.00000
# 189                           Samoa         WSM    26.172      15.30000
# 188              West Bank and Gaza         PSE    30.394      46.60000
# 187                         Vanuatu         VUT    26.739      11.30000
# 186                         Vietnam         VNM    15.537      43.90000
# 185           Virgin Islands (U.S.)         VIR    10.700      45.30000
# 184                   Venezuela, RB         VEN    19.842      54.90000
# 183  St. Vincent and the Grenadines         VCT    16.306      52.00000
# ...

# %%
stats[['CountryName','Birthrate']]
# Out:
#                         CountryName Birthrate
# 0                             Aruba    10.244
# 1                       Afghanistan    35.253
# 2                            Angola    45.985
# 3                           Albania    12.877
# 4              United Arab Emirates    11.044
# 5                         Argentina    17.716
# 6                           Armenia    13.308
# 7               Antigua and Barbuda    16.447
# 8                         Australia    13.200
# 9                           Austria     9.400
# 10                       Azerbaijan    18.300
# 11                          Burundi    44.151
# 12                          Belgium    11.200
# 13                            Benin    36.440
# 14                     Burkina Faso    40.551
# 15                       Bangladesh    20.142
# 16                         Bulgaria     9.200
# 17                          Bahrain    15.040
# 18                     Bahamas, The    15.339
# ...

# %%
#stats['Birthrate'] * stats['Internetusers']
# Out:
#     Birthrate Internetusers
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
# 5         NaN           NaN
# 6         NaN           NaN
# 7         NaN           NaN
# 8         NaN           NaN
# 9         NaN           NaN
# 10        NaN           NaN
# 11        NaN           NaN
# 12        NaN           NaN
# 13        NaN           NaN
# 14        NaN           NaN
# 15        NaN           NaN
# 16        NaN           NaN
# 17        NaN           NaN
# 18        NaN           NaN
# 19        NaN           NaN
# 20        NaN           NaN
# 21        NaN           NaN
# 22        NaN           NaN
# 23        NaN           NaN
# 24        NaN           NaN
# 25        NaN           NaN
# 26        NaN           NaN
# 27        NaN           NaN
# 28        NaN           NaN
# 29        NaN           NaN
# ..        ...           ...
# 165       NaN           NaN
# ...

# %%
stats.Birthrate * stats.Internetusers
# Out:
#     Birthrate Internetusers
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
# 5         NaN           NaN
# 6         NaN           NaN
# 7         NaN           NaN
# 8         NaN           NaN
# 9         NaN           NaN
# 10        NaN           NaN
# 11        NaN           NaN
# 12        NaN           NaN
# 13        NaN           NaN
# 14        NaN           NaN
# 15        NaN           NaN
# 16        NaN           NaN
# 17        NaN           NaN
# 18        NaN           NaN
# 19        NaN           NaN
# 20        NaN           NaN
# 21        NaN           NaN
# 22        NaN           NaN
# 23        NaN           NaN
# 24        NaN           NaN
# 25        NaN           NaN
# 26        NaN           NaN
# 27        NaN           NaN
# 28        NaN           NaN
# 29        NaN           NaN
# ..        ...           ...
# 165       NaN           NaN
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# (CountryName,)      195 non-null object
# (CountryCode,)      195 non-null object
# (Birthrate,)        195 non-null float64
# (Internetusers,)    195 non-null float64
# (IncomeGroup,)      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
result
# Out:
#     Birthrate Internetusers
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
# 5         NaN           NaN
# 6         NaN           NaN
# 7         NaN           NaN
# 8         NaN           NaN
# 9         NaN           NaN
# 10        NaN           NaN
# 11        NaN           NaN
# 12        NaN           NaN
# 13        NaN           NaN
# 14        NaN           NaN
# 15        NaN           NaN
# 16        NaN           NaN
# 17        NaN           NaN
# 18        NaN           NaN
# 19        NaN           NaN
# 20        NaN           NaN
# 21        NaN           NaN
# 22        NaN           NaN
# 23        NaN           NaN
# 24        NaN           NaN
# 25        NaN           NaN
# 26        NaN           NaN
# 27        NaN           NaN
# 28        NaN           NaN
# 29        NaN           NaN
# ..        ...           ...
# 165       NaN           NaN
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.distplot(stats['Internetusers'])

# %%
sns.lmplot(data=stats, x='Internetusers', y = 'Birthrate')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-2d3614369520> in <module>
# ----> 1 sns.lmplot(data=stats, x='Internetusers', y = 'Birthrate')
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     576     if sharex:
#     577         for ax in facets.axes.flat:
# --> 578             ax.scatter(data[x], np.ones(len(data)) * data[y].mean()).remove()
#     579
#     580     # Draw the regression plot on each facet
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# (CountryName,)      195 non-null object
# (CountryCode,)      195 non-null object
# (Birthrate,)        195 non-null float64
# (Internetusers,)    195 non-null float64
# (IncomeGroup,)      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB
